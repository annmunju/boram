# %%
import pandas as pd

# %%
df_novel = pd.read_csv('novel_story_sep.csv', lineterminator='\n')
df_sing = pd.read_csv('songChart_sep.csv', lineterminator='\n')

# %%
df_novel.columns
# Out:
# Index(['itemId', 'title', 'story', 'review', 'piece'], dtype='object')

# %%
df_sing.columns
# Out:
# Index(['id', 'year', 'songid', 'title', 'singer', 'lyrics', 'lyrics_sep'], dtype='object')

# %%
df_novel['all_story'] = df_novel['story'] + df_novel['review'] + df_novel['piece']
df_novel_new = df_novel[['title', 'all_story']]

# %%
df_sing['all_story'] = df_sing['lyrics_sep']
df_sing_new = df_sing[['title', 'all_story']]

# %%
df = pd.concat([df_novel_new, df_sing_new])

# %% [markdown]
# # LDA 모델에 들어갈 객체(dictionary, corpus) 만들고 학습시키기

# %%
import gensim
gensim.__version__
# Out:
# '3.8.1'

# %%
import gensim
from gensim import corpora, models
from gensim.models import CoherenceModel
from gensim.test.utils import common_corpus
from gensim.models.wrappers import LdaMallet

# %%
novel = df_novel['story'] + df_novel['review'] + df_novel['piece']
sing = df_sing['lyrics_sep']

# %%
stories = novel.append(sing)

# %%
data_word = []
for story in stories:
    data = list(str(story).split())
    data_word.append(data)

# %%
id2word = corpora.Dictionary(data_word)

# %%
id2word.filter_extremes(no_below = 5) # 5회 이하로 등장한 단어는 삭제
texts = data_word
corpus = [id2word.doc2bow(text) for text in texts]

mallet_path = '../mallet-2.0.8/bin/mallet' 
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=60, random_seed=12, id2word=id2word)

coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=texts, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print(coherence_ldamallet) #응집성 지수
# Out:
# 0.38603649556679703

# %%
# Select the model and print the topics
# optimal_model = model_list[model_list_num]
optimal_model = ldamallet
model_topics = optimal_model.show_topics(formatted=False)
print(optimal_model.print_topics()[5])
# Out:
# (38, '0.050*"청소년" + 0.030*"꿈" + 0.029*"학교" + 0.023*"자신" + 0.017*"선생님" + 0.014*"친구" + 0.010*"어른" + 0.010*"성장" + 0.009*"일" + 0.009*"현실"')

# %%
def format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=texts, Data=df):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    #ldamodel[corpus]: lda_model에 corpus를 넣어 각 토픽 당 확률을 알 수 있음
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num,topn=10)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    print(type(sent_topics_df))

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
#     sent_topics_df = pd.concat([Data['itemId'],Data['title'],Data['story'], sent_topics_df], axis=1)

    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=texts, Data=df)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Format
df_topic_story = df_topic_sents_keywords

# 각 문서에 대한 토픽 내림차순
df_topic_sort=df_topic_story.sort_values(by=['Dominant_Topic'])

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# %%
sent_topics_sorteddf_mallet[['Perc_Contribution', 'Dominant_Topic', 'Topic_Keywords']]
# Out:
#       Perc_Contribution  Dominant_Topic  \
# 87               0.6246             0.0
# 9                0.4780             1.0
# 881              0.3586             2.0
# 1948             0.4449             3.0
# 834              0.4788             4.0
# 459              0.4045             5.0
# 510              0.8700             6.0
# 115              0.6415             7.0
# 842              0.8215             8.0
# 976              0.4769             9.0
# 564              0.5939            10.0
# 465              0.2927            11.0
# 1973             0.5417            12.0
# 163              0.5505            13.0
# 1806             0.4409            14.0
# 863              0.5526            15.0
# 1028             0.3342            16.0
# 869              0.3878            17.0
# 285              0.5800            18.0
# 629              0.3200            19.0
# 160              0.2680            20.0
# 667              0.3684            21.0
# 580              0.3851            22.0
# 1060             0.6349            23.0
# 261              0.3684            24.0
# 583              0.9096            25.0
# 959              0.4528            26.0
# 1398             0.5680            27.0
# 484              0.5713            28.0
# 2049             0.2636            29.0
# 1840             0.5506            30.0
# 393              0.4502            31.0
# 480              0.9289            32.0
# 928              0.4156            33.0
# 4                0.8086            34.0
# 1                0.7818            35.0
# 491              0.6533            36.0
# 895              0.8151            37.0
# 776              0.4791            38.0
# 1025             0.3610            39.0
# 5                0.6791            40.0
# 1385             0.2791            41.0
# 666              0.7891            42.0
# 1607             0.4502            43.0
# 372              0.8295            44.0
# 924              0.4017            45.0
# 176              0.7062            46.0
# 983              0.3409            47.0
# 581              0.7771            48.0
# 1938             0.5016            49.0
# 57               0.3729            50.0
# 263              0.6779            51.0
# 801              0.6085            52.0
# 1112             0.6026            53.0
# 1079             0.7447            54.0
# 1829             0.3623            55.0
# 960              0.3574            56.0
# 1850             0.1898            57.0
# 1056             0.8143            58.0
# 1082             0.3915            59.0
#
#                                  Topic_Keywords
# 87            면, 현실, 마음, 마법, 집, 동식, 나, 사람, 말, 큰
# 9         서점, 섬, 유, 사진, 인생, 여인, 마치, 프랑스, 기욤, 뮈소
# 881          죽음, 삶, 쪽, 죽은, 시작, 끝, 의미, 사고, 인생, 생
# 1948     다시, 눈물, 가슴, 제발, 한번, 많이, 이별, 안녕, 이제, 다른
# 834       사회, 인간, 세계, 세상, 시대, 자신, 삶, 노동, 자살, 현실
# 459        시간, 황, 생각, 이서, 자신, 상점, 말, 미래, 발견, 기억
# 510          말, 놈, 얼굴, 공격, 막, 노인, 화살, 죽, 상대, 무슨
# 115           말, 사람, 세상, 나, 생각, 너, 약속, 줄, 수도, 살
# 842           왕, 말, 눈, 혼, 조선, 황제, 너, 아비, 어찌, 그녀
# 976       회사, 사람, 일, 배, 에피소드, 팀, 시간, 시장, 직원, 사장
# 564   주인공, 말, 장르, 스토리, 재미, 실제, 소재, 판타지, 등장, 다양한
# 465        엄마, 아빠, 할머니, 집, 가족, 쪽, 날, 마음, 본문, 동생
# 1973     보고, 바람, 하늘, 겨울, 멀리, 시간, 향기, 거리, 모습, 바다
# 163        드라마, 밤, 스노볼, 여인, 나, 자신, 꽃, 신의, 마음, 손
# 1806     노래, 그때, 얘기, 그냥, 누가, 어디, 소리, 혼자, 여기, 아마
# 863           손, 말, 자신, 자기, 장소, 입, 문, 감정, 눈물, 곧
# 1028      쪽, 사람, 도시, 본문, 소녀, 마을, 작은, 시작, 자신, 사실
# 869              집, 말, 씨, 방, 몸, 아내, 일, 손, 모습, 눈
# 285      수학, 아이, 중학교, 대학, 학생, 노을, 교사, 생활, 말, 여기
# 629          나, 말, 쪽, 자신, 기억, 생각, 존재, 나를, 과거, 날
# 160         친구, 마음, 말, 시작, 관계, 고민, 걸, 연애, 위로, 애
# 667       인간, 움, 존재, 자신, 아름다, 욕망, 생명, 서로, 뜻, 마리
# 580    사건, 미스터리, 일본, 살인, 범인, 형사, 경찰, 추리, 살해, 수사
# 1060    한국, 소개, 대표, 세계, 모습, 영어, 이해, 교수, 한국어, 표현
# 261       쪽, 자신, 영혼, 의미, 사람, 합니다, 나, 향, 있습니다, 요
# 583         미국, 뉴욕, 자신, 말, 자매, 그녀, 생각, 치, 쪽, 사실
# 959      우주, 세계, 지구, 인류, 인간, 과학, 미래, 자신, 행성, 존재
# 1398        아이, 친구, 말, 자신, 존재, 일, 모습, 선, 누나, 폭력
# 484      리, 사람, 미국, 세상, 그림, 이상, 변호사, 시작, 세계, 사건
# 2049         사람, 건, 생각, 일, 선택, 정, 왜, 소리, 사실, 누구
# 1840    오늘, 하루, 자꾸, 매일, 머리, 자꾸만, 어디, 느낌, 기분, 몰래
# 393        영화, 돈, 사람, 동네, 카페, 일상, 술, 서울, 시작, 서로
# 480        영, 달빛, 웹소설, 그린, 시작, 궁, 마음, 세자, 쪽, 세상
# 928         사람, 샘, 임신, 갑자기, 병, 거리, 사이, 피, 인생, 일
# 4         몸, 감정, 새로운, 주인공, 나, 세상, 말, 타인, 공감, 소년
# 1           역사, 전쟁, 일본, 땅, 삶, 시대, 사람, 조선, 나라, 돈
# 491       이상, 악마, 얼굴, 로맨스, 이나, 호랑이, 신, 생각, 건, 눈
# 895        박완서, 결정, 판, 사회, 사진, 글, 한국, 삶, 시기, 언어
# 776      청소년, 꿈, 학교, 자신, 선생님, 친구, 어른, 성장, 일, 현실
# 1025     시대, 세기, 대표, 평가, 생각, 주의, 중국, 문화, 역사, 당시
# 5       꿈, 가게, 손님, 사람, 재난, 음악, 백화점, 달러, 프랭크, 주인
# 1385    생각, 마음, 마지막, 당신, 조금, 순간, 처음, 라면, 준비, 점점
# 666        얼굴, 눈, 자신, 공주, 머리, 검은, 무슨, 월, 소리, 그녀
# 1607     우리, 모두, 모든, 하나, 이제, 세상, 우린, 함께, 아직, 없이
# 372          삶, 사람, 인생, 말, 자신, 고독, 일, 자기, 평생, 코
# 924       세상, 살, 인생, 맛, 감동, 소년, 별, 시절, 어른, 할아버지
# 176       고양이, 인간, 여행, 돌, 세월, 나무, 세계, 시작, 무, 도시
# 983       남자, 여자, 사람, 세상, 거기, 소리, 냄새, 누구, 우화, 정
# 581      진실, 사실, 비밀, 사람, 복수, 사건, 충격, 발견, 편지, 교수
# 1938    그대, 기억, 눈물, 추억, 다시, 가슴, 이름, 모습, 혼자, 목소리
# 57          일, 삶, 순간, 집, 언니, 타인, 누군가, 향, 젊은, 감정
# 263          삶, 살, 고통, 마을, 소녀, 힘, 자신, 의지, 세상, 빛
# 801        스릴러, 세계, 상, 당신, 기억, 영국, 미국, 스, 수상, 눈
# 1112   nan, 운명, 도깨비, 악몽, 인연, 유진, 연인, 세상, 우연, 소녀
# 1079         한국, 핀, 나, 부터, 월간, 결혼, 시, 유령, 서도, 임
# 1829     사람, 마음, 상처, 서로, 누구, 모습, 슬픔, 아픔, 미소, 이유
# 960        세계, 집, 현실, 방식, 편의, 글, 언어, 의미, 발표, 미래
# 1850    그녀, 여성, 자신, 남편, 결혼, 여자, 앨리스, 남자, 사실, 연인
# 1056          말, 명, 흰, 눈, 완성, 이순신, 길, 척, 싸움, 사람
# 1082        아버지, 아들, 말, 어머니, 가족, 나, 딸, 살, 성, 어린

# %%
df_topic_story.value_counts('Dominant_Topic').sort_index()
# Out:
# Dominant_Topic
# 0.0      15
# 1.0       6
# 2.0      12
# 3.0     247
# 4.0      15
# 5.0      11
# 6.0       9
# 7.0       6
# 8.0      18
# 9.0       6
# 10.0     13
# 11.0     18
# 12.0     53
# 13.0     12
# 14.0     61
# 15.0     10
# 16.0     15
# 17.0     13
# 18.0     10
# 19.0     25
# 20.0     18
# 21.0      9
# 22.0     36
# 23.0     13
# 24.0     13
# 25.0      5
# 26.0     27
# 27.0     15
# 28.0      8
# 29.0      9
# 30.0    136
# 31.0     15
# 32.0      5
# 33.0      7
# 34.0      8
# 35.0     14
# 36.0     14
# 37.0     10
# 38.0     13
# 39.0     25
# 40.0      8
# 41.0     32
# 42.0      4
# 43.0    208
# 44.0     12
# 45.0     16
# 46.0     12
# 47.0     34
# 48.0      9
# 49.0    193
# 50.0     16
# 51.0     10
# 52.0     25
# 53.0    487
# 54.0      9
# 55.0     38
# 56.0     25
# 57.0     15
# 58.0     10
# 59.0      9
# dtype: int64

# %%
topic_1 = df_topic_story[df_topic_story['Dominant_Topic']==1]
topic_2 = df_topic_story[df_topic_story['Dominant_Topic']==30]
topic_2[topic_2['Perc_Contribution'] > 0.4]
# Out:
#       Dominant_Topic  Perc_Contribution  \
# 1610            30.0             0.4953
# 1765            30.0             0.4076
# 1838            30.0             0.4524
# 1840            30.0             0.5506
# 1847            30.0             0.4172
#
#                                Topic_Keywords  \
# 1610  오늘, 하루, 자꾸, 매일, 머리, 자꾸만, 어디, 느낌, 기분, 몰래
# 1765  오늘, 하루, 자꾸, 매일, 머리, 자꾸만, 어디, 느낌, 기분, 몰래
# 1838  오늘, 하루, 자꾸, 매일, 머리, 자꾸만, 어디, 느낌, 기분, 몰래
# 1840  오늘, 하루, 자꾸, 매일, 머리, 자꾸만, 어디, 느낌, 기분, 몰래
# 1847  오늘, 하루, 자꾸, 매일, 머리, 자꾸만, 어디, 느낌, 기분, 몰래
#
#                                                       0
# 1610  [자꾸, 두근두근, 가슴, 자꾸만, 자꾸만, 자꾸, 파오, 같이, 자꾸만, 자꾸만,...
# 1765  [월요일, 아마, 화요일, 보이지, 수요일, 뭔가, 느낌, 목요일, 그냥, 왠지, ...
# 1838  [취향, 저격, 취향, 저격, 느낌, 머리, 발끝, 취향, 저격, 가지, 안달, 자...
# 1840  [아예, 아예, 아예, 아예, 아예, 아예, 아예, 아예, 아예, 아예, 싱긋싱긋,...
# 1847  [월요일, 아마, 화요일, 보이지, 수요일, 뭔가, 느낌, 목요일, 그냥, 왠지, ...

# %%
df_topic_sort[df_topic_sort['Perc_Contribution'] > 0.5]
# Out:
#       Dominant_Topic  Perc_Contribution                      Topic_Keywords  \
# 23               0.0             0.6221   면, 현실, 마음, 마법, 집, 동식, 나, 사람, 말, 큰
# 87               0.0             0.6246   면, 현실, 마음, 마법, 집, 동식, 나, 사람, 말, 큰
# 510              6.0             0.8700  말, 놈, 얼굴, 공격, 막, 노인, 화살, 죽, 상대, 무슨
# 296              6.0             0.5015  말, 놈, 얼굴, 공격, 막, 노인, 화살, 죽, 상대, 무슨
# 513              6.0             0.8440  말, 놈, 얼굴, 공격, 막, 노인, 화살, 죽, 상대, 무슨
# ...              ...                ...                                 ...
# 325             54.0             0.5382  한국, 핀, 나, 부터, 월간, 결혼, 시, 유령, 서도, 임
# 747             54.0             0.5117  한국, 핀, 나, 부터, 월간, 결혼, 시, 유령, 서도, 임
# 1079            54.0             0.7447  한국, 핀, 나, 부터, 월간, 결혼, 시, 유령, 서도, 임
# 1057            58.0             0.8120   말, 명, 흰, 눈, 완성, 이순신, 길, 척, 싸움, 사람
# 1056            58.0             0.8143   말, 명, 흰, 눈, 완성, 이순신, 길, 척, 싸움, 사람
#
#                                                       0
# 23    [당신, 감고, 시간, 있습니까, 위험한, 소원, 이루어지는, 위저드, 베이커, 리...
# 87    [당신, 감고, 시간, 있습니까, 판매, 위험한, 소원, 이루어지는, 위저드, 베이...
# 510   [하북, 남쪽, 심주현, 위치, 유서, 깊은, 상계, 가문, 장씨, 남쪽, 중요, ...
# 296   [하북, 남쪽, 심주현, 위치, 유서, 깊은, 상계, 가문, 장씨, 남쪽, 중요, ...
# 513   [하북, 남쪽, 심주현, 위치, 유서, 깊은, 상계, 가문, 장씨, 남쪽, 중요, ...
# ...                                                 ...
# 325   [당대, 한국, 대적, 서도, 첨예한, 핀, 설선, 당대, 한국, 대적, 서도, 첨...
# 747   [당대, 한국, 대적, 서도, 첨예한, 핀, 설선, 서른, 당대, 한국, 대적, 서...
# 1079  [당대, 한국, 대적, 서도, 첨예한, 핀, 설선, 여섯, 대하, 여당, 한국, 대...
# 1057  [박은우, 장편, 명량, 불패, 신화, 명랑해전을, 승리, 이끌, 기, 악전, 고투...
# 1056  [박은우, 장편, 명량, 불패, 신화, 명랑해전을, 승리, 이끌, 기, 악전, 고투...
#
# [94 rows x 4 columns]
