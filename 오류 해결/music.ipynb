# %%
import pandas as pd

# %%
df = pd.read_csv('music.csv', on_bad_lines='skip')

# %%
df
# Out:
#         id  year    songid         title        singer  \
# 0        1  2001     19807         벌써 일년       브라운 아이즈
# 1        2  2003    421409            점점       브라운 아이즈
# 2        3  2003    485716      정말 사랑했을까    브라운 아이드 소울
# 3        4  2001     89806    I Love You           포지션
# 4        5  2001     32574   또 한번 사랑은 가고           이기찬
# ...    ...   ...       ...           ...           ...
# 1023  1025  2021  33077234  Life Goes On         방탄소년단
# 1024  1026  2021  32224272        METEOR  창모 (CHANGMO)
# 1025  1027  2021   1944399      Timeless        SG 워너비
# 1026  1028  2021  33655994       Weekend  태연 (TAEYEON)
# 1027  1029  2021  30244931            봄날         방탄소년단
#
#                                                  lyrics  \
# 0     처음이라 그래 며칠뒤엔 괜찮아져 그 생각만으로 벌써 일년이 너와 만든 기념일마다 슬...
# 1     점점 넌 멀어지나봐 웃고 있는 날 봐 때론 며칠씩 편하게 지내 점점 널 잊는 것 같...
# 2     좋았나봐 널 많이 아꼈나봐 다시 못견디게 아픈걸 보니 가슴에서 자꾸만 열이 나고 널...
# 3     I love you 사랑한다는 이 말 밖에는 해줄 말이 없네요 I love you ...
# ...
