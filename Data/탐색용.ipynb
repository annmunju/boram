# %%
import pandas as pd

# %%
color = pd.read_csv('color.csv')
music = pd.read_csv('music.csv')
novel = pd.read_csv('novel (1).csv', sep='\t')
test = pd.read_csv('val.csv', index_col=0)
train = pd.read_csv('data.csv', index_col=0)
novel_end = pd.read_csv('소설_책내용_서평기반_LDA_완료.csv', index_col=0)

# %%
novel_end[['title', 'Dominant_Topic', 'Topic_Keywords']][:20]
# Out:
#                                      title  Dominant_Topic  \
# 0                                    파친코 1             4.0
# 1                                    파친코 2             4.0
# 2                  불편한 편의점(40만부 기념 벚꽃 에디션)             9.0
# 3                                      아몬드             0.0
# 4   달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)             9.0
# 5                                    테라피스트             5.0
# 6                             달러구트 꿈 백화점 2             9.0
# 7                               달러구트 꿈 백화점             9.0
# 8                            센 강의 이름 모를 여인             6.0
# 9                                     밝은 밤             2.0
# 10                                    작별인사             8.0
# 11                                지구 끝의 온실             2.0
# 12                                망원동 브라더스             9.0
# 13                            체리새우: 비밀글입니다             9.0
# 14                      우리가 빛의 속도로 갈 수 없다면             2.0
# ...

# %%
pd.options.display.max_rows = 8
pd.options.display.min_rows = 8

pd.options.display.max_columns = 12

# %%
test
# Out:
#        target                                               data
# 0           1                      요즘 젊은 직원들 대하기가 여간 조심스러운게 아니야.
# 1           0             요즘 이 책을 읽는데 너무 괜찮은 책 인 것 같아. 마음이 평온해져.
# 2           0  치료를 계속 받아야 하는 친구가 있는데 병원비 때문에 퇴원한다는 거 내가 돈을 빌려줬어.
# 3           0        남편이 공들여 요리를 해주는 날은 사랑받는 기분이 들어. 그게 바로 오늘이고!
# ...       ...                                                ...
# 24919       4                                    각자의 시간을 가져봐야겠어.
# 24920       3                    잔소리만 하는 게 아니야. 옆에 있는 것도 이제 지겨워.
# 24921       4                      그래야 할거 같아 내가 배우고 싶은걸 생각해봐야겠어.
# 24922       0            지금까지 열심히 살았고 앞으로도 열심히 살면 만족스러운 노후가 되겠지.
#
# [24923 rows x 2 columns]
