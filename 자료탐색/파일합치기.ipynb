# %%
import pandas as pd

# %%
i = 1
df = pd.read_csv(f'도서목록_샘플_{i}페이지.csv')
df.head()
# Out:
#       itemId                    title   pubDate  \
# 0  281536876                    파친코 1  20180309
# 1  281536885                    파친코 2  20180309
# 2  348921505  불편한 편의점(40만부 기념 벚꽃 에디션)  20210420
# 3  354595636                     저주토끼  20220401
# 4  266107628                      아몬드  20170331
#
#                                        coverSmallUrl  \
# 0  https://bimage.interpark.com/partner/goods_ima...
# 1  https://bimage.interpark.com/partner/goods_ima...
# 2  https://bimage.interpark.com/partner/goods_ima...
# 3  https://bimage.interpark.com/partner/goods_ima...
# 4  https://bimage.interpark.com/partner/goods_ima...
#
#                                        coverLargeUrl publisher  \
# 0  https://bimage.interpark.com/partner/goods_ima...      문학사상
# 1  https://bimage.interpark.com/partner/goods_ima...      문학사상
# 2  https://bimage.interpark.com/partner/goods_ima...     나무옆의자
# 3  https://bimage.interpark.com/partner/goods_ima...        아작
# ...

# %%
for i in range(2, 11):
    new_df = pd.read_csv(f'도서목록_샘플_{i}페이지.csv')
    df = pd.concat([df, new_df])
df
# Out:
#        itemId                    title   pubDate  \
# 0   281536876                    파친코 1  20180309
# 1   281536885                    파친코 2  20180309
# 2   348921505  불편한 편의점(40만부 기념 벚꽃 에디션)  20210420
# 3   354595636                     저주토끼  20220401
# 4   266107628                      아몬드  20170331
# ..        ...                      ...       ...
# 95  267622859               스타벅스에 간 소녀  20170519
# 96  268027541                 데미안(초판본)  20170530
# 97  267463159                 마티네의 끝에서  20170522
# 98  268319305      아이 엠 넘버 포 5: 세븐의 복수  20170622
# 99  268217229                    상실 여행  20170621
#
#                                         coverSmallUrl  \
# 0   https://bimage.interpark.com/partner/goods_ima...
# 1   https://bimage.interpark.com/partner/goods_ima...
# 2   https://bimage.interpark.com/partner/goods_ima...
# 3   https://bimage.interpark.com/partner/goods_ima...
# 4   https://bimage.interpark.com/partner/goods_ima...
# ...
